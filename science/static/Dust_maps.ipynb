# %% [markdown]
# Compare the coadded depth with the extragalactic extincted depth

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import lsst.sims.maf.db as db
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.metricBundles as metricBundles
import numpy as np
import healpy as hp

# %%
# Set up the database connection
opsdb = db.OpsimDatabase('baseline_nexp2_v1.7_10yrs.db')
outDir = 'dustMaps'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
nside=128
bundleList = []
slicer1 = slicers.HealpixSlicer(nside=nside)
slicer2 = slicers.HealpixSlicer(nside=nside, useCache=False)
metric1 = metrics.Coaddm5Metric()
metric2 = metrics.ExgalM5()
filters = ['u', 'g', 'r', 'i', 'z', 'y']
mins = {'u': 23.7, 'g':25.2, 'r':22.5, 'i': 24.6, 'z': 23.7,'y':22.8 }
maxes = {'u': 27.6, 'g':28.5, 'r': 28.5, 'i': 27.9, 'z': 27.6,'y':26.1 }

for filtername in filters:
    sql = 'filter="%s"' % filtername
    plotDict = {'colorMin': mins[filtername], 'colorMax': maxes[filtername]}
    bundleList.append(metricBundles.MetricBundle(metric1, slicer1, sql))
    bundleList.append(metricBundles.MetricBundle(metric2, slicer2, sql, plotDict=plotDict))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bundleDict = metricBundles.makeBundlesDictFromList(bundleList)
bgroup = metricBundles.MetricBundleGroup(bundleDict, opsdb, outDir=outDir, resultsDb=resultsDb)
bgroup.runAll()
# Out:
# Querying database SummaryAllProps with constraint filter="z" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 397742 visits
# Running:  ['opsim_CoaddM5_z_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 404071 visits
# Running:  ['opsim_CoaddM5_y_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_y_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 455743 visits
# Running:  ['opsim_CoaddM5_i_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 452001 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 205011 visits
# Running:  ['opsim_CoaddM5_g_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" for columns ['filter', 'fieldDec', 'fieldRA', 'fiveSigmaDepth']
# Found 130925 visits
# Running:  ['opsim_CoaddM5_u_HEAL']
# Completed metric generation.
# Running:  ['opsim_ExgalM5_u_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %%
bgroup.plotAll(closefigs=False)
# Out:
# Plotting figures with "filter="z"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 213 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.2104  dipole: lon: 113.395, lat: -73.3753, amp: 0.430361
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 4709 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 24.5695  dipole: lon: 81.593, lat: -39.4191, amp: 0.854612
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="y"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 732 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 24.68  dipole: lon: 103.656, lat: -4.83254, amp: 0.235518
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 5696 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 24.2007  dipole: lon: 81.3059, lat: -2.61982, amp: 0.745852
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="i"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 241 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.9252  dipole: lon: 114.354, lat: -69.4605, amp: 0.398937
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 5552 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.0929  dipole: lon: 80.997, lat: -32.8366, amp: 0.999025
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 218 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/plots/spatialPlotters.py:224: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(fignum, figsize=plotDict['figsize'])
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 26.4792  dipole: lon: 110.137, lat: -70.9847, amp: 0.430174
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 6745 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.3902  dipole: lon: 79.2579, lat: -30.4591, amp: 1.23791
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="g"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 270 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 26.5302  dipole: lon: 110.637, lat: -77.5312, amp: 0.475627
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 9393 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.0468  dipole: lon: 77.3742, lat: -29.1356, amp: 1.57963
#   warnings.warn(
# Plotting complete.
# Plotting figures with "filter="u"" constraint now.
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 583 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 25.4807  dipole: lon: 110.27, lat: -25.8856, amp: 0.214092
#   warnings.warn(
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:106: UserWarning: Optimal bin calculation tried to make 11509 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/healpy/pixelfunc.py:1581: UserWarning: monopole: 23.7228  dipole: lon: 74.9216, lat: -4.1203, amp: 2.12429
#   warnings.warn(
# Plotting complete.

# %%
i1=6
i2 = i1+1

diff = bundleList[i1].metricValues - bundleList[i2].metricValues
hp.mollview(diff, max=20)
